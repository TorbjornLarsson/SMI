# %% [markdown]
# <a href="https://colab.research.google.com/github/TorbjornLarsson/SMI/blob/main/mnist_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt

# use GPU for computations if possible
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# temporarily patch this script until the MNIST data set download issue is resolved
# https://github.com/pytorch/vision/issues/1938
import urllib.request
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]
urllib.request.install_opener(opener)

# %% [markdown]
# # Classification of hand-written digits
#
# We start by downloading and extracting the MNIST data set.

# %%
trainset = torchvision.datasets.MNIST(root='./data', train=True,
                                      download=True, transform=transforms.ToTensor())

testset = torchvision.datasets.MNIST(root='./data', train=False,
                                     download=True, transform=transforms.ToTensor())

# extract a complete PyTorch dataset
def extract(dataset):
    datasize = len(dataset)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=datasize, shuffle=False)
    return next(iter(dataloader))

# extract all test images and labels into PyTorch tensors
# the training data will be loaded in batches during training
test_X, test_Y = extract(testset)

# %% [markdown]
# ## The model
#
# The input data $X$ are grayscale images of $28\times 28$ pixels. The first dimension will be the number of data points that are provided to the network. The input data is flattend into a matrix with $28 \times 28 = 784$ columns using `X.view(-1, 784)`, where each colum represents one pixel. We then apply first the linear transformation $X W + b$ and then the softmax function to obtain the class probabilities predicted by the model.

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # the weights of dimension (784, 10)
        # self.W = nn.Parameter(torch.zeros(784, 10))
        # the offset vector of dimension (10,)
        # self.b = nn.Parameter(torch.zeros(10))
        #U1 = 200 # number of units in the first hidden layer
        #self.W1 = nn.Parameter(0.1 * torch.randn(784, U1))
        #self.b1 = nn.Parameter(torch.zeros(U1))
        U1 = 4
        self.W1 = nn.Parameter(0.1 * torch.randn(U1, 1, 5, 5))
        self.b1 = nn.Parameter(torch.ones(U1)/10)
        U2 = 8
        self.W2 = nn.Parameter(0.1 * torch.randn(U2, 4, 5, 5))
        self.b2 = nn.Parameter(torch.ones(U2)/10)
        U3 = 12
        self.W3 = nn.Parameter(0.1 * torch.randn(U3, 8, 4, 4))
        self.b3 = nn.Parameter(torch.ones(U3)/10)

        #U2 = 100 # number of units in the second hidden layer
        #self.W2 = nn.Parameter(0.1 * torch.randn(U1, U2))
        #self.b2 = nn.Parameter(torch.zeros(U2))
        #U3 = 60 # number of units in the third hidden layer
        #self.W3 = nn.Parameter(0.1 * torch.randn(U2, U3))
        #self.b3 = nn.Parameter(torch.zeros(U3))
        U4 = 200 # number of units in the FOURTH hidden layer
        self.W4 = nn.Parameter(0.1 * torch.randn(588, U4))
        self.b4 = nn.Parameter(torch.zeros(U4))
        self.W5 = nn.Parameter(0.1 * torch.randn(U4, 10))
        #self.b5 = nn.Parameter(torch.zeros(10))
        self.b5 = nn.Parameter(torch.ones(10)/10)

    def forward(self, X):
        # flatten the data into a matrix with 28 x 28 = 784 columns
        #X = X.view(-1, 784)
        # compute the linear transformation
        # Z = X.mm(self.W) + self.b
        # apply the softmax function
        # G = F.softmax(Z, dim=1)
        #Q1 = F.relu(X.mm(self.W1) + self.b1)
        Q1 = F.relu(F.conv2d(X, self.W1, bias=self.b1, stride=1, padding=2))
        Q2 = F.relu(F.conv2d(Q1, self.W2, bias=self.b2, stride=2, padding=2))
        Q3 = F.relu(F.conv2d(Q2, self.W3, bias=self.b3, stride=2, padding=1))
        Q3flat = Q3.view(-1, 588)

        #Q2 = F.relu(Q1.mm(self.W2) + self.b2)
        #Q3 = F.relu(Q2.mm(self.W3) + self.b3)
        Q4 = F.relu(Q3flat.mm(self.W4) + self.b4)
        #G = F.softmax(Q4.mm(self.W5) + self.b5, dim=1)
        Z = Q4.mm(self.W5) + self.b5
        return Z

# %% [markdown]
# ## The training
#
# We define the cross-entropy for the predicted probabilities $G$ (10-dimensional vectors) and the labels $Y$ (integers between 0 and 9).

# %%
def crossentropy(G, Y):
    # convert labels to onehot encoding
    Y_onehot = torch.eye(10, device=device)[Y]

    return -(Y_onehot * G.log()).sum(dim = 1).mean()

# %% [markdown]
# The next lines evaluate the accuracy of the predictions.

# %%
def accuracy(G, Y):
    return (G.argmax(dim=1) == Y).float().mean()

# %% [markdown]
# We are ready to train the network.

# %%
# initialize the test and training error statistics
test_accuracy = []
test_crossentropy = []
test_iter = []
train_accuracy = []
train_crossentropy = []
train_iter = []

# initialize the neural network and move it to the GPU if needed
net = Net()
net.to(device)

# define the optimization algorithm
learningrate = 0.003
optimizer = optim.Adam(net.parameters(), lr=learningrate)

# define the data loader for batches of the training data
batchsize = 100
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batchsize, num_workers=2, shuffle=True)

# perform multiple training steps
total_iterations = 4000 # total number of iterations
t = 0 # current iteration
done = False
while not done:
    for (batch_X, batch_Y) in trainloader:
        # move batch to the GPU if needed
        batch_X, batch_Y = batch_X.to(device), batch_Y.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward pass
        batch_G = net(batch_X)
        loss = F.cross_entropy(batch_G, batch_Y)

        # backpropagation
        loss.backward()

        # perform gradient descent step
        optimizer.step()

        # don't bother too much about the following lines!
        with torch.no_grad():
            # evaluate the performance on the training data at every 10th iteration
            if t % 10 == 0:
                train_crossentropy.append(loss.item())
                train_accuracy.append(accuracy(batch_G, batch_Y).item())
                train_iter.append(t)

            # evaluate the performance on the test data at every 100th iteration
            if t % 100 == 0:
                # move test data to the GPU if needed
                X, Y = test_X.to(device), test_Y.to(device)

                # compute predictions for the test data
                G = net(X)
                test_crossentropy.append(crossentropy(G, Y).item())
                test_accuracy.append(accuracy(G, Y).item())
                test_iter.append(t)

                # print the iteration number and the accuracy of the predictions
                print(f"Step {t:5d}: train accuracy {100 * train_accuracy[-1]:6.2f}% " \
                      f"train cross-entropy {train_crossentropy[-1]:5.2f}  " \
                      f"test accuracy {100 * test_accuracy[-1]:6.2f}% " \
                      f"test cross-entropy {test_crossentropy[-1]:5.2f}")

        # stop the training after the specified number of iterations
        t += 1
        if t > total_iterations:
            done = True
            break
# Out:
# Step     0: train accuracy  12.00% train cross-entropy  2.38  test accuracy  23.60% test cross-entropy   nan
# Step   100: train accuracy  97.00% train cross-entropy  0.11  test accuracy  93.91% test cross-entropy   nan
# Step   200: train accuracy  97.00% train cross-entropy  0.08  test accuracy  95.15% test cross-entropy   nan
# Step   300: train accuracy  98.00% train cross-entropy  0.12  test accuracy  96.11% test cross-entropy   nan
# Step   400: train accuracy  97.00% train cross-entropy  0.06  test accuracy  97.09% test cross-entropy   nan
# Step   500: train accuracy  98.00% train cross-entropy  0.03  test accuracy  97.54% test cross-entropy   nan
# Step   600: train accuracy  98.00% train cross-entropy  0.03  test accuracy  97.67% test cross-entropy   nan
# Step   700: train accuracy  97.00% train cross-entropy  0.07  test accuracy  97.75% test cross-entropy   nan
# Step   800: train accuracy  98.00% train cross-entropy  0.06  test accuracy  97.99% test cross-entropy   nan
# Step   900: train accuracy  99.00% train cross-entropy  0.09  test accuracy  98.00% test cross-entropy   nan
# Step  1000: train accuracy  96.00% train cross-entropy  0.10  test accuracy  98.25% test cross-entropy   nan
# Step  1100: train accuracy  98.00% train cross-entropy  0.05  test accuracy  98.20% test cross-entropy   nan
# Step  1200: train accuracy  98.00% train cross-entropy  0.22  test accuracy  98.49% test cross-entropy   nan
# Step  1300: train accuracy  96.00% train cross-entropy  0.10  test accuracy  98.35% test cross-entropy   nan
# Step  1400: train accuracy  98.00% train cross-entropy  0.04  test accuracy  98.19% test cross-entropy   nan
# Step  1500: train accuracy  97.00% train cross-entropy  0.07  test accuracy  98.43% test cross-entropy   nan
# Step  1600: train accuracy  97.00% train cross-entropy  0.06  test accuracy  98.46% test cross-entropy   nan
# Step  1700: train accuracy  99.00% train cross-entropy  0.08  test accuracy  98.28% test cross-entropy   nan
# Step  1800: train accuracy  99.00% train cross-entropy  0.04  test accuracy  97.92% test cross-entropy   nan
# Step  1900: train accuracy  99.00% train cross-entropy  0.03  test accuracy  98.64% test cross-entropy   nan
# Step  2000: train accuracy  99.00% train cross-entropy  0.04  test accuracy  98.52% test cross-entropy   nan
# Step  2100: train accuracy  99.00% train cross-entropy  0.02  test accuracy  97.99% test cross-entropy   nan
# Step  2200: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.39% test cross-entropy   nan
# Step  2300: train accuracy 100.00% train cross-entropy  0.01  test accuracy  98.48% test cross-entropy   nan
# Step  2400: train accuracy 100.00% train cross-entropy  0.01  test accuracy  98.65% test cross-entropy   nan
# Step  2500: train accuracy  98.00% train cross-entropy  0.05  test accuracy  98.67% test cross-entropy   nan
# Step  2600: train accuracy  99.00% train cross-entropy  0.02  test accuracy  98.34% test cross-entropy   nan
# Step  2700: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.68% test cross-entropy   nan
# Step  2800: train accuracy 100.00% train cross-entropy  0.01  test accuracy  98.67% test cross-entropy   nan
# Step  2900: train accuracy  99.00% train cross-entropy  0.02  test accuracy  98.74% test cross-entropy   nan
# Step  3000: train accuracy  99.00% train cross-entropy  0.04  test accuracy  98.44% test cross-entropy   nan
# Step  3100: train accuracy  99.00% train cross-entropy  0.02  test accuracy  98.38% test cross-entropy   nan
# Step  3200: train accuracy  99.00% train cross-entropy  0.01  test accuracy  98.68% test cross-entropy   nan
# Step  3300: train accuracy  98.00% train cross-entropy  0.06  test accuracy  98.56% test cross-entropy   nan
# Step  3400: train accuracy  99.00% train cross-entropy  0.02  test accuracy  98.29% test cross-entropy   nan
# Step  3500: train accuracy  96.00% train cross-entropy  0.06  test accuracy  98.57% test cross-entropy   nan
# Step  3600: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.70% test cross-entropy   nan
# Step  3700: train accuracy 100.00% train cross-entropy  0.00  test accuracy  98.62% test cross-entropy   nan
# Step  3800: train accuracy  99.00% train cross-entropy  0.02  test accuracy  98.64% test cross-entropy   nan
# Step  3900: train accuracy 100.00% train cross-entropy  0.01  test accuracy  98.73% test cross-entropy   nan
# Step  4000: train accuracy  99.00% train cross-entropy  0.03  test accuracy  98.40% test cross-entropy   nan

# %% [markdown]
# ## The evaluation
#
# The remaining code produces the plots needed to evaluate the training and predictions.

# %%
# plot the cross-entropy
plt.plot(train_iter, train_crossentropy, 'b-', label='Training data (mini-batch)')
plt.plot(test_iter, test_crossentropy, 'r-', label='Test data')
plt.xlabel('Iteration')
plt.ylabel('Cross-entropy')
plt.ylim([0, min(test_crossentropy) * 3])
plt.title('Cross-entropy')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the accuracy
plt.plot(train_iter, train_accuracy, 'b-', label='Training data (mini-batch)')
plt.plot(test_iter, test_accuracy, 'r-', label='Test data')
plt.xlabel('Iteration')
plt.ylabel('Prediction accuracy')
plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('Prediction accuracy')
plt.grid(True)
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1008110143.py in <cell line: 0>()
#       4 plt.xlabel('Iteration')
#       5 plt.ylabel('Cross-entropy')
# ----> 6 plt.ylim([0, min(test_crossentropy) * 3])
#       7 plt.title('Cross-entropy')
#       8 plt.grid(True)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in ylim(*args, **kwargs)
#    2158     if not args and not kwargs:
#    2159         return ax.get_ylim()
# -> 2160     ret = ax.set_ylim(*args, **kwargs)
#    2161     return ret
#    2162
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    4015                 raise TypeError("Cannot pass both 'top' and 'ymax'")
#    4016             top = ymax
# -> 4017         return self.yaxis._set_lim(bottom, top, emit=emit, auto=auto)
#    4018
#    4019     get_yscale = _axis_method_wrapper("yaxis", "get_scale")
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in _set_lim(self, v0, v1, emit, auto)
#    1226         self.axes._process_unit_info([(name, (v0, v1))], convert=False)
#    1227         v0 = self.axes._validate_converted_limits(v0, self.convert_units)
# -> 1228         v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#    1229
#    1230         if v0 is None or v1 is None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _validate_converted_limits(self, limit, convert)
#    3702             if (isinstance(converted_limit, Real)
#    3703                     and not np.isfinite(converted_limit)):
# -> 3704                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3705             return converted_limit
#    3706
#
# ValueError: Axis limits cannot be NaN or Inf

# %%
# evaluate the network on 100 random test images
with torch.no_grad():
    # obtain 100 random samples from the test data set
    random_X, random_Y = next(iter(torch.utils.data.DataLoader(testset, batch_size=100, shuffle=True)))

    # move data to the GPU if needed
    random_X, random_Y = random_X.to(device), random_Y.to(device)

    # compute the predictions for the sampled inputs
    random_G = net(random_X)
    random_Yhat = random_G.argmax(dim=1)

    # sort the predictions with the incorrect ones first
    indices_incorrect_first = (random_Yhat == random_Y).float().argsort()

# plot the images
num_rows = 10
num_cols = 10
num_images = num_rows * num_cols
plt.figure(figsize=(num_cols, num_rows))

for i, index in enumerate(indices_incorrect_first, 1):
    plt.subplot(num_rows, num_cols, i)
    plt.xticks([])
    plt.yticks([])

    # plot the image
    plt.imshow(random_X[index, :, :].view(28, 28).cpu().numpy(), cmap=plt.cm.binary)

    # add the prediction as annotation (incorrect predictions in red, correct ones in blue)
    color = 'blue' if random_Yhat[index] == random_Y[index] else 'red'
    plt.text(0, 25, random_Yhat[index].item(), fontsize=25, color=color)

plt.show()
